# %%
from qiskit import QuantumCircuit, transpile # type: ignore
from qiskit_aer import Aer # type: ignore
from qiskit.visualization import plot_histogram # type: ignore
print("Qiskit kurulumu başarılı!")

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()


simulator = Aer.get_backend('aer_simulator')
t_qc = transpile(qc, simulator)
result = simulator.run(t_qc).result()


counts = result.get_counts(qc)
plot_histogram(counts)
# Out:
# Qiskit kurulumu başarılı!

# %%
from qiskit import QuantumCircuit # type: ignore 
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager # type: ignore
from qiskit_ibm_runtime import EstimatorV2 as Estimator # type: ignore
 
# Create a new circuit with two qubits
qc = QuantumCircuit(3)
 
# Add a Hadamard gate to qubit 0
qc.h(0)
qc.h(1)
 
# Perform a controlled-X gate on qubit 1, controlled by qubit 0
qc.cx(0, 1)
qc.cx(1,2)
 
# Return a drawing of the circuit using MatPlotLib ("mpl"). This is the
# last line of the cell, so the drawing appears in the cell output.
# Remove the "mpl" argument to get a text drawing.
qc.draw("mpl")

# %%
# from qiskit_ibm_runtime import QiskitRuntimeService
 
# If you did not previously save your credentials, use the following line instead:
# service = QiskitRuntimeService(channel="ibm_quantum", token="<MY_IBM_QUANTUM_TOKEN>")
# service = QiskitRuntimeService()
 
# backend = service.least_busy(simulator=False, operational=True)
 
# Convert to an ISA circuit and layout-mapped observables.
# pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
# isa_circuit = pm.run(qc)
 
# isa_circuit.draw('mpl', idle_wires=False)
# Out:
# ---------------------------------------------------------------------------
# AccountNotFoundError                      Traceback (most recent call last)
# Cell In[2], line 5
#       1 from qiskit_ibm_runtime import QiskitRuntimeService
#       3 # If you did not previously save your credentials, use the following line instead:
#       4 # service = QiskitRuntimeService(channel="ibm_quantum", token="<MY_IBM_QUANTUM_TOKEN>")
# ----> 5 service = QiskitRuntimeService()
#       7 backend = service.least_busy(simulator=False, operational=True)
#       9 # Convert to an ISA circuit and layout-mapped observables.
#
# File c:\Users\MONSTER\miniconda3\envs\yeni_env\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:129, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, channel_strategy, private_endpoint)
#      82 """QiskitRuntimeService constructor
#      83
#      84 An account is selected in the following order:
#    (...)
#     125     IBMInputValueError: If an input is invalid.
#     126 """
#     127 super().__init__()
# --> 129 self._account = self._discover_account(
#     130     token=token,
#     131     url=url,
#     132     instance=instance,
#     133     channel=channel,
#     134     filename=filename,
#     135     name=name,
#     136     proxies=ProxyConfiguration(**proxies) if proxies else None,
#     137     verify=verify,
#     138     channel_strategy=channel_strategy,
#     139 )
#     141 if private_endpoint is not None:
#     142     self._account.private_endpoint = private_endpoint
#
# File c:\Users\MONSTER\miniconda3\envs\yeni_env\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:250, in QiskitRuntimeService._discover_account(self, token, url, instance, channel, filename, name, proxies, verify, channel_strategy)
#     248 # channel is not defined yet, get it from the AccountManager
#     249 if account is None:
# --> 250     account = AccountManager.get(filename=filename)
#     252 if instance:
#     253     account.instance = instance
#
# File c:\Users\MONSTER\miniconda3\envs\yeni_env\Lib\site-packages\qiskit_ibm_runtime\accounts\management.py:197, in AccountManager.get(cls, filename, name, channel)
#     194     if account_name in all_config:
#     195         return Account.from_saved_format(all_config[account_name])
# --> 197 raise AccountNotFoundError("Unable to find account.")
#
# AccountNotFoundError: 'Unable to find account.'
